# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import pandas as pd
from sqlalchemy import create_engine
import re
import pickle

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

from sklearn import multioutput
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.naive_bayes import GaussianNB, MultinomialNB

from sklearn.multioutput import MultiOutputClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split, cross_val_score

import sklearn.metrics as metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import TruncatedSVD
from sklearn.base import BaseEstimator, TransformerMixin

import pickle
import re
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/rishimadhav/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/rishimadhav/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/rishimadhav/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# load data from database
engine = create_engine('sqlite:///DisasterResponse.db')
df = pd.read_sql_table("labeledmessages", con=engine)
X = df['message']
y = df.drop(columns=['id', 'message', 'original', 'genre'], axis=1)

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
url_regex = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'

# %%
def tokenize(text):
    """
    Receives text data and processes it
    Args: Text Data (column of messages)
    Returns: Tokenized text
    """
    # get list of URLS using regex
    detected_urls = re.findall(url_regex, text)

    # replace each url in text string with placeholder
    for url in detected_urls:
        text = text.replace(url, 'urlplaceholder')
    
    # tokenize text
    tokens = word_tokenize(text)

    # initiate lemmatizer
    lemmatizer = WordNetLemmatizer()

    # iterate through each token and lemmatize, normalize, remove leading/trailing white space and return clean tokenized text
    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)
    
    return clean_tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
pipeline = Pipeline([
    ('vect', CountVectorizer(tokenizer=tokenize)),
    ('tfidf', TfidfTransformer()),
    ('clf', RandomForestClassifier())
])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
# Split data into train and test sets

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x7fc990e729d0>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('clf', RandomForestClassifier())])

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
# define a function to evaluate models
def evaluate_model(model, X_test, y_test, label_names, print_reports=False):
    pred = pd.DataFrame(model.predict(X_test), columns=label_names)

    metrics = []
    for col in label_names:
        # Store metrics in a list
        report = classification_report(y_test[col], pred[col])
        scores = report.split('accuracy')[1].split()
        metrics.append([float(scores[i]) for i in [0,4,5,6,10,11,12]])

        # Print classification report
        if print_reports:
            print('-' * 53)
            print(f'Label: {col}')
            print(report)
    
    # Convert metrics list into a Dataframe
    metric_names = ['accuracy', 'macro_avg_precision', 'macro_avg_recall', 'macro_avg_f1', 'weighted_avg_precision', 'weighted_avg_recall', 'weighted_avg_f1']
    return pd.DataFrame(metrics, columns=metric_names, index=label_names)

evaluate_model(pipeline, X_test, y_test, y_test.columns)
# Out:
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                         accuracy  macro_avg_precision  macro_avg_recall  \
# related                     0.82                 0.79              0.66
# request                     0.89                 0.89              0.71
# offer                       1.00                 0.50              0.50
# aid_related                 0.75                 0.78              0.71
# medical_help                0.92                 0.83              0.50
# medical_products            0.95                 0.81              0.51
# search_and_rescue           0.97                 0.73              0.50
# security                    0.98                 0.74              0.50
# military                    0.97                 0.48              0.50
# water                       0.94                 0.94              0.58
# food                        0.91                 0.91              0.63
# shelter                     0.92                 0.91              0.55
# clothing                    0.99                 0.91              0.52
# money                       0.98                 0.89              0.52
# missing_people              0.99                 0.49              0.50
# refugees                    0.97                 0.48              0.50
# death                       0.95                 0.98              0.52
# other_aid                   0.87                 0.73              0.51
# infrastructure_related      0.93                 0.47              0.50
# transport                   0.95                 0.98              0.50
# buildings                   0.95                 0.79              0.51
# electricity                 0.98                 0.99              0.50
# tools                       0.99                 0.50              0.50
# hospitals                   0.99                 0.49              0.50
# shops                       1.00                 0.50              0.50
# aid_centers                 0.99                 0.49              0.50
# other_infrastructure        0.96                 0.48              0.50
# weather_related             0.84                 0.86              0.73
# floods                      0.93                 0.92              0.57
# storm                       0.91                 0.87              0.57
# fire                        0.99                 0.49              0.50
# earthquake                  0.95                 0.93              0.73
# cold                        0.98                 0.99              0.50
# other_weather               0.95                 0.98              0.50
# direct_report               0.86                 0.87              0.66
#
#                         macro_avg_f1  weighted_avg_precision  \
# related                         0.69                    0.81
# request                         0.76                    0.89
# offer                           0.50                    0.99
# aid_related                     0.72                    0.77
# medical_help                    0.48                    0.90
# medical_products                0.50                    0.93
# search_and_rescue               0.50                    0.95
# security                        0.50                    0.97
# military                        0.49                    0.93
# water                           0.63                    0.94
# food                            0.69                    0.91
# shelter                         0.57                    0.92
# clothing                        0.53                    0.98
# money                           0.53                    0.97
# missing_people                  0.50                    0.98
# refugees                        0.49                    0.93
# death                           0.52                    0.96
# other_aid                       0.48                    0.83
# infrastructure_related          0.48                    0.87
# transport                       0.50                    0.96
# buildings                       0.50                    0.93
# electricity                     0.50                    0.98
# tools                           0.50                    0.99
# hospitals                       0.50                    0.98
# shops                           0.50                    0.99
# aid_centers                     0.50                    0.98
# other_infrastructure            0.49                    0.91
# weather_related                 0.76                    0.85
# floods                          0.60                    0.93
# storm                           0.60                    0.91
# fire                            0.50                    0.98
# earthquake                      0.79                    0.94
# cold                            0.50                    0.98
# other_weather                   0.49                    0.95
# direct_report                   0.70                    0.86
#
#                         weighted_avg_recall  weighted_avg_f1
# related                                0.82             0.79
# request                                0.89             0.88
# offer                                  1.00             0.99
# aid_related                            0.75             0.73
# medical_help                           0.92             0.88
# medical_products                       0.95             0.93
# search_and_rescue                      0.97             0.95
# security                               0.98             0.97
# military                               0.97             0.95
# water                                  0.94             0.93
# food                                   0.91             0.89
# shelter                                0.92             0.89
# clothing                               0.99             0.98
# money                                  0.98             0.97
# missing_people                         0.99             0.98
# refugees                               0.97             0.95
# death                                  0.95             0.93
# other_aid                              0.87             0.81
# infrastructure_related                 0.93             0.90
# transport                              0.95             0.93
# buildings                              0.95             0.92
# electricity                            0.98             0.97
# tools                                  0.99             0.99
# hospitals                              0.99             0.98
# shops                                  1.00             0.99
# aid_centers                            0.99             0.98
# other_infrastructure                   0.96             0.93
# weather_related                        0.84             0.82
# floods                                 0.93             0.90
# storm                                  0.91             0.89
# fire                                   0.99             0.98
# earthquake                             0.95             0.94
# cold                                   0.98             0.97
# other_weather                          0.95             0.93
# direct_report                          0.86             0.83

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
# Parameter grid to search
parameters = {
    "clf__max_depth" : [4, 5, 10],
    "clf__max_features" : [2, 3],
    "clf__min_samples_leaf" : [3, 4, 5],
    "clf__n_estimators" : [100, 200, 300]
} 

gs = GridSearchCV(pipeline, parameters, cv=4, n_jobs=12, verbose=2)
gs.fit(X_train, y_train)
gs.best_params_
# Out:
# Fitting 4 folds for each of 54 candidates, totalling 216 fits
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  23.1s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  23.8s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  23.9s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  23.9s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  33.3s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  33.1s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  33.8s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  34.2s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  42.7s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  42.7s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  43.4s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  43.9s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  23.2s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  22.6s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  22.7s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  22.9s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  34.4s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  34.7s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  34.6s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  34.5s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  24.9s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  25.0s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  25.2s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  25.4s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  46.2s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  46.6s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  47.4s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  46.8s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  37.1s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  37.1s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  37.0s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  37.3s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  25.7s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  26.0s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  46.3s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  26.6s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  26.1s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  46.9s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  47.1s
# [CV] END clf__max_depth=4, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  47.2s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  35.8s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  35.7s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  35.7s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  35.8s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  25.6s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  25.1s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  25.4s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  25.4s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  46.6s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  47.1s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  46.7s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  47.5s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  35.5s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  35.8s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  35.7s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  35.8s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  25.5s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  25.5s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  25.6s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  46.8s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  46.6s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  46.6s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  26.2s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  47.3s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  37.1s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  36.8s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  37.2s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  36.7s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  26.1s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  26.3s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  26.3s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  25.9s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  49.3s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  49.2s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  49.9s
# [CV] END clf__max_depth=4, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  50.3s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  39.4s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  40.0s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  39.4s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  39.7s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  27.6s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  27.6s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  27.7s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  50.6s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  27.6s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  51.0s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  51.3s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  51.3s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  40.0s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  40.2s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  40.1s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  40.2s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  28.7s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  28.8s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  28.8s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  28.8s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  52.3s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  52.0s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  52.2s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  52.1s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  39.0s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  39.4s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  39.7s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  39.7s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  27.6s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  27.6s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  50.2s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  27.6s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  27.7s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  50.7s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  51.1s
# [CV] END clf__max_depth=5, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  51.0s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  39.9s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  40.1s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  40.5s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  40.4s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  28.1s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  28.7s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  28.7s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  28.6s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  53.6s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  53.7s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  53.8s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  54.1s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  41.5s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  42.1s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  41.8s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  42.4s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  29.0s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  29.2s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  53.5s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  29.0s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  29.6s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  54.1s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  54.1s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  54.6s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  40.9s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  40.8s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  40.4s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  41.0s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  28.3s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  28.6s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  28.5s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  28.3s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  52.2s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  52.1s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  52.2s
# [CV] END clf__max_depth=5, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  52.4s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  39.9s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  40.2s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  39.9s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  41.3s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  29.8s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  29.9s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  29.7s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  53.2s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  30.0s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  53.7s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  53.7s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  54.0s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  42.5s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  42.4s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  42.5s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  28.7s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  41.8s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  28.8s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  29.1s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  29.0s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  53.6s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  53.9s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  54.2s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  54.2s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  41.2s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  41.5s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  41.6s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  42.0s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  29.1s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  29.2s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  29.4s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  53.8s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  53.6s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=100; total time=  29.5s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  54.3s
# [CV] END clf__max_depth=10, clf__max_features=2, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  54.1s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  41.5s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  41.6s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  41.4s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=200; total time=  41.3s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  29.5s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  29.4s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  29.6s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=100; total time=  29.3s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  54.8s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  54.6s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  54.6s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=3, clf__n_estimators=300; total time=  54.9s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  41.3s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  41.7s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  41.8s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=200; total time=  42.2s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  29.2s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  29.0s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  29.1s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  53.7s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  53.4s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=100; total time=  29.6s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  53.7s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=4, clf__n_estimators=300; total time=  53.6s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  33.9s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  32.9s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  33.7s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=200; total time=  31.7s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  30.8s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  29.6s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  30.1s
# [CV] END clf__max_depth=10, clf__max_features=3, clf__min_samples_leaf=5, clf__n_estimators=300; total time=  29.7s
# {'clf__max_depth': 4,
#  'clf__max_features': 2,
#  'clf__min_samples_leaf': 3,
#  'clf__n_estimators': 100}

# %% [markdown]
# Best parameters for a Random Forest Classifier pipeline:
# {'clf__max_depth': 4,
#  'clf__max_features': 2,
#  'clf__min_samples_leaf': 3,
#  'clf__n_estimators': 100}

# %% [markdown]
# **6.1 Evaluate Pipeline with best parameters**

# %%
rndclf = gs.best_estimator_
report_rndclf = evaluate_model(rndclf, X_test, y_test, y_test.columns)
report_rndclf
# Out:
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                         accuracy  macro_avg_precision  macro_avg_recall  \
# related                     0.76                 0.38               0.5
# request                     0.83                 0.41               0.5
# offer                       1.00                 0.50               0.5
# aid_related                 0.58                 0.29               0.5
# medical_help                0.92                 0.46               0.5
# medical_products            0.95                 0.47               0.5
# search_and_rescue           0.97                 0.48               0.5
# security                    0.98                 0.49               0.5
# military                    0.97                 0.48               0.5
# water                       0.93                 0.47               0.5
# food                        0.89                 0.44               0.5
# shelter                     0.91                 0.45               0.5
# clothing                    0.98                 0.49               0.5
# money                       0.98                 0.49               0.5
# missing_people              0.99                 0.49               0.5
# refugees                    0.97                 0.48               0.5
# death                       0.95                 0.48               0.5
# other_aid                   0.87                 0.43               0.5
# infrastructure_related      0.94                 0.47               0.5
# transport                   0.95                 0.48               0.5
# buildings                   0.95                 0.47               0.5
# electricity                 0.98                 0.49               0.5
# tools                       0.99                 0.50               0.5
# hospitals                   0.99                 0.49               0.5
# shops                       1.00                 0.50               0.5
# aid_centers                 0.99                 0.49               0.5
# other_infrastructure        0.96                 0.48               0.5
# weather_related             0.72                 0.36               0.5
# floods                      0.92                 0.46               0.5
# storm                       0.90                 0.45               0.5
# fire                        0.99                 0.49               0.5
# earthquake                  0.91                 0.45               0.5
# cold                        0.98                 0.49               0.5
# other_weather               0.95                 0.47               0.5
# direct_report               0.80                 0.40               0.5
#
#                         macro_avg_f1  weighted_avg_precision  \
# related                         0.43                    0.58
# request                         0.45                    0.69
# offer                           0.50                    0.99
# aid_related                     0.37                    0.34
# medical_help                    0.48                    0.84
# medical_products                0.49                    0.90
# search_and_rescue               0.49                    0.94
# security                        0.50                    0.96
# military                        0.49                    0.93
# water                           0.48                    0.87
# food                            0.47                    0.79
# shelter                         0.48                    0.83
# clothing                        0.50                    0.97
# money                           0.49                    0.95
# missing_people                  0.50                    0.98
# refugees                        0.49                    0.93
# death                           0.49                    0.91
# other_aid                       0.46                    0.75
# infrastructure_related          0.48                    0.87
# transport                       0.49                    0.91
# buildings                       0.49                    0.89
# electricity                     0.49                    0.96
# tools                           0.50                    0.99
# hospitals                       0.50                    0.98
# shops                           0.50                    0.99
# aid_centers                     0.50                    0.98
# other_infrastructure            0.49                    0.91
# weather_related                 0.42                    0.52
# floods                          0.48                    0.84
# storm                           0.47                    0.81
# fire                            0.50                    0.98
# earthquake                      0.48                    0.82
# cold                            0.49                    0.96
# other_weather                   0.49                    0.90
# direct_report                   0.44                    0.64
#
#                         weighted_avg_recall  weighted_avg_f1
# related                                0.76             0.66
# request                                0.83             0.75
# offer                                  1.00             0.99
# aid_related                            0.58             0.42
# medical_help                           0.92             0.88
# medical_products                       0.95             0.92
# search_and_rescue                      0.97             0.95
# security                               0.98             0.97
# military                               0.97             0.95
# water                                  0.93             0.90
# food                                   0.89             0.83
# shelter                                0.91             0.87
# clothing                               0.98             0.98
# money                                  0.98             0.96
# missing_people                         0.99             0.98
# refugees                               0.97             0.95
# death                                  0.95             0.93
# other_aid                              0.87             0.81
# infrastructure_related                 0.94             0.90
# transport                              0.95             0.93
# buildings                              0.95             0.92
# electricity                            0.98             0.97
# tools                                  0.99             0.99
# hospitals                              0.99             0.98
# shops                                  1.00             0.99
# aid_centers                            0.99             0.98
# other_infrastructure                   0.96             0.93
# weather_related                        0.72             0.60
# floods                                 0.92             0.88
# storm                                  0.90             0.86
# fire                                   0.99             0.98
# earthquake                             0.91             0.86
# cold                                   0.98             0.97
# other_weather                          0.95             0.93
# direct_report                          0.80             0.71

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
report_rndclf.mean()
# Out:
# accuracy                  0.924286
# macro_avg_precision       0.460571
# macro_avg_recall          0.500000
# macro_avg_f1              0.479143
# weighted_avg_precision    0.860000
# weighted_avg_recall       0.924286
# weighted_avg_f1           0.888000
# dtype: float64

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %% [markdown]
# **Try Naive Bayes and ADA Boost Classifier and check for the above metrics**

# %% [markdown]
# ***8.1 Naive Bayes Classifier***

# %%
# Trying Naive Bayes classifier

from sklearn.naive_bayes import MultinomialNB

pipe_nb = Pipeline([ 
    ('vect', CountVectorizer(tokenizer=tokenize)),
    ('tfidf', TfidfTransformer()),
    ('clf', multioutput.MultiOutputClassifier(MultinomialNB(alpha=0.01)))
])

pipe_nb.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x7fc990e729d0>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('clf',
#                  MultiOutputClassifier(estimator=MultinomialNB(alpha=0.01)))])

# %%
pipe_nb.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'vect', 'tfidf', 'clf', 'vect__analyzer', 'vect__binary', 'vect__decode_error', 'vect__dtype', 'vect__encoding', 'vect__input', 'vect__lowercase', 'vect__max_df', 'vect__max_features', 'vect__min_df', 'vect__ngram_range', 'vect__preprocessor', 'vect__stop_words', 'vect__strip_accents', 'vect__token_pattern', 'vect__tokenizer', 'vect__vocabulary', 'tfidf__norm', 'tfidf__smooth_idf', 'tfidf__sublinear_tf', 'tfidf__use_idf', 'clf__estimator__alpha', 'clf__estimator__class_prior', 'clf__estimator__fit_prior', 'clf__estimator', 'clf__n_jobs'])

# %%
# Grid search for parameters
params = {
    'vect__ngram_range' : [(1,1), (1,2)],
    'vect__max_df' : [0.1, 0.2],
    'vect__max_features' : [None, 100, 1000, 10000] 
}

gs_nb = GridSearchCV(pipe_nb, params, cv=4, n_jobs=16, verbose=2)
gs_nb.fit(X_train, y_train)
gs_nb.best_params_
# Out:
# Fitting 4 folds for each of 16 candidates, totalling 64 fits
# [CV] END vect__max_df=0.1, vect__max_features=None, vect__ngram_range=(1, 1); total time=  18.5s
# [CV] END vect__max_df=0.1, vect__max_features=100, vect__ngram_range=(1, 1); total time=  20.1s
# [CV] END vect__max_df=0.1, vect__max_features=None, vect__ngram_range=(1, 1); total time=  23.3s
# [CV] END vect__max_df=0.1, vect__max_features=100, vect__ngram_range=(1, 1); total time=  24.4s
# [CV] END vect__max_df=0.1, vect__max_features=100, vect__ngram_range=(1, 2); total time=  24.2s
# [CV] END vect__max_df=0.1, vect__max_features=None, vect__ngram_range=(1, 1); total time=  25.5s
# [CV] END vect__max_df=0.1, vect__max_features=100, vect__ngram_range=(1, 1); total time=  25.7s
# [CV] END vect__max_df=0.1, vect__max_features=None, vect__ngram_range=(1, 1); total time=  26.3s
# [CV] END vect__max_df=0.1, vect__max_features=100, vect__ngram_range=(1, 1); total time=  26.8s
# [CV] END vect__max_df=0.1, vect__max_features=None, vect__ngram_range=(1, 2); total time=  28.4s
# [CV] END vect__max_df=0.1, vect__max_features=None, vect__ngram_range=(1, 2); total time=  28.7s
# [CV] END vect__max_df=0.1, vect__max_features=100, vect__ngram_range=(1, 2); total time=  28.4s
# [CV] END vect__max_df=0.1, vect__max_features=100, vect__ngram_range=(1, 2); total time=  28.7s
# [CV] END vect__max_df=0.1, vect__max_features=100, vect__ngram_range=(1, 2); total time=  29.1s
# [CV] END vect__max_df=0.1, vect__max_features=None, vect__ngram_range=(1, 2); total time=  31.4s
# [CV] END vect__max_df=0.1, vect__max_features=None, vect__ngram_range=(1, 2); total time=  32.5s
# [CV] END vect__max_df=0.1, vect__max_features=1000, vect__ngram_range=(1, 1); total time=  21.7s
# [CV] END vect__max_df=0.1, vect__max_features=1000, vect__ngram_range=(1, 1); total time=  21.9s
# [CV] END vect__max_df=0.1, vect__max_features=1000, vect__ngram_range=(1, 1); total time=  21.8s
# [CV] END vect__max_df=0.1, vect__max_features=1000, vect__ngram_range=(1, 1); total time=  20.5s
# [CV] END vect__max_df=0.1, vect__max_features=10000, vect__ngram_range=(1, 1); total time=  21.1s
# [CV] END vect__max_df=0.1, vect__max_features=10000, vect__ngram_range=(1, 1); total time=  21.2s
# [CV] END vect__max_df=0.1, vect__max_features=10000, vect__ngram_range=(1, 1); total time=  21.0s
# [CV] END vect__max_df=0.1, vect__max_features=10000, vect__ngram_range=(1, 1); total time=  21.4s
# [CV] END vect__max_df=0.1, vect__max_features=1000, vect__ngram_range=(1, 2); total time=  24.6s
# [CV] END vect__max_df=0.1, vect__max_features=1000, vect__ngram_range=(1, 2); total time=  24.2s
# [CV] END vect__max_df=0.1, vect__max_features=1000, vect__ngram_range=(1, 2); total time=  24.5s
# [CV] END vect__max_df=0.1, vect__max_features=1000, vect__ngram_range=(1, 2); total time=  24.9s
# [CV] END vect__max_df=0.1, vect__max_features=10000, vect__ngram_range=(1, 2); total time=  25.3s
# [CV] END vect__max_df=0.1, vect__max_features=10000, vect__ngram_range=(1, 2); total time=  25.9s
# [CV] END vect__max_df=0.1, vect__max_features=10000, vect__ngram_range=(1, 2); total time=  25.1s
# [CV] END vect__max_df=0.1, vect__max_features=10000, vect__ngram_range=(1, 2); total time=  25.8s
# [CV] END vect__max_df=0.2, vect__max_features=None, vect__ngram_range=(1, 1); total time=  21.5s
# [CV] END vect__max_df=0.2, vect__max_features=None, vect__ngram_range=(1, 1); total time=  21.1s
# [CV] END vect__max_df=0.2, vect__max_features=None, vect__ngram_range=(1, 1); total time=  21.8s
# [CV] END vect__max_df=0.2, vect__max_features=None, vect__ngram_range=(1, 1); total time=  21.7s
# [CV] END vect__max_df=0.2, vect__max_features=100, vect__ngram_range=(1, 1); total time=  22.4s
# [CV] END vect__max_df=0.2, vect__max_features=100, vect__ngram_range=(1, 1); total time=  22.1s
# [CV] END vect__max_df=0.2, vect__max_features=100, vect__ngram_range=(1, 1); total time=  23.2s
# [CV] END vect__max_df=0.2, vect__max_features=100, vect__ngram_range=(1, 1); total time=  23.0s
# [CV] END vect__max_df=0.2, vect__max_features=None, vect__ngram_range=(1, 2); total time=  28.2s
# [CV] END vect__max_df=0.2, vect__max_features=None, vect__ngram_range=(1, 2); total time=  28.2s
# [CV] END vect__max_df=0.2, vect__max_features=None, vect__ngram_range=(1, 2); total time=  30.2s
# [CV] END vect__max_df=0.2, vect__max_features=None, vect__ngram_range=(1, 2); total time=  30.1s
# [CV] END vect__max_df=0.2, vect__max_features=100, vect__ngram_range=(1, 2); total time=  26.1s
# [CV] END vect__max_df=0.2, vect__max_features=100, vect__ngram_range=(1, 2); total time=  27.9s
# [CV] END vect__max_df=0.2, vect__max_features=100, vect__ngram_range=(1, 2); total time=  26.8s
# [CV] END vect__max_df=0.2, vect__max_features=1000, vect__ngram_range=(1, 1); total time=  24.4s
# [CV] END vect__max_df=0.2, vect__max_features=100, vect__ngram_range=(1, 2); total time=  28.2s
# [CV] END vect__max_df=0.2, vect__max_features=1000, vect__ngram_range=(1, 1); total time=  25.1s
# [CV] END vect__max_df=0.2, vect__max_features=1000, vect__ngram_range=(1, 1); total time=  24.6s
# [CV] END vect__max_df=0.2, vect__max_features=1000, vect__ngram_range=(1, 1); total time=  23.5s
# [CV] END vect__max_df=0.2, vect__max_features=1000, vect__ngram_range=(1, 2); total time=  22.8s
# [CV] END vect__max_df=0.2, vect__max_features=1000, vect__ngram_range=(1, 2); total time=  22.6s
# [CV] END vect__max_df=0.2, vect__max_features=10000, vect__ngram_range=(1, 1); total time=  19.0s
# [CV] END vect__max_df=0.2, vect__max_features=10000, vect__ngram_range=(1, 1); total time=  19.4s
# [CV] END vect__max_df=0.2, vect__max_features=1000, vect__ngram_range=(1, 2); total time=  22.2s
# [CV] END vect__max_df=0.2, vect__max_features=1000, vect__ngram_range=(1, 2); total time=  22.2s
# [CV] END vect__max_df=0.2, vect__max_features=10000, vect__ngram_range=(1, 1); total time=  19.0s
# [CV] END vect__max_df=0.2, vect__max_features=10000, vect__ngram_range=(1, 1); total time=  18.4s
# [CV] END vect__max_df=0.2, vect__max_features=10000, vect__ngram_range=(1, 2); total time=  18.8s
# [CV] END vect__max_df=0.2, vect__max_features=10000, vect__ngram_range=(1, 2); total time=  17.2s
# [CV] END vect__max_df=0.2, vect__max_features=10000, vect__ngram_range=(1, 2); total time=  16.8s
# [CV] END vect__max_df=0.2, vect__max_features=10000, vect__ngram_range=(1, 2); total time=  15.6s
# {'vect__max_df': 0.1, 'vect__max_features': 10000, 'vect__ngram_range': (1, 2)}

# %%
#Evaluate NB Classifier Model with best parameters
multinb = gs_nb.best_estimator_
report_multinb = evaluate_model(multinb, X_test, y_test, y_test.columns)
report_multinb
# Out:
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/rishimadhav/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                         accuracy  macro_avg_precision  macro_avg_recall  \
# related                     0.82                 0.76              0.70
# request                     0.89                 0.80              0.81
# offer                       0.99                 0.58              0.53
# aid_related                 0.76                 0.75              0.75
# medical_help                0.93                 0.77              0.62
# medical_products            0.95                 0.72              0.65
# search_and_rescue           0.97                 0.86              0.53
# security                    0.98                 0.62              0.50
# military                    0.97                 0.75              0.65
# water                       0.94                 0.78              0.70
# food                        0.92                 0.80              0.76
# shelter                     0.93                 0.81              0.69
# clothing                    0.98                 0.71              0.66
# money                       0.98                 0.78              0.57
# missing_people              0.99                 0.79              0.56
# refugees                    0.97                 0.69              0.54
# death                       0.96                 0.81              0.67
# other_aid                   0.87                 0.73              0.55
# infrastructure_related      0.93                 0.63              0.54
# transport                   0.95                 0.75              0.59
# buildings                   0.95                 0.79              0.62
# electricity                 0.98                 0.82              0.57
# tools                       0.99                 0.50              0.50
# hospitals                   0.99                 0.49              0.50
# shops                       0.99                 0.60              0.51
# aid_centers                 0.99                 0.74              0.51
# other_infrastructure        0.95                 0.62              0.54
# weather_related             0.84                 0.81              0.79
# floods                      0.93                 0.76              0.73
# storm                       0.93                 0.81              0.76
# fire                        0.99                 0.74              0.52
# earthquake                  0.94                 0.89              0.75
# cold                        0.98                 0.86              0.61
# other_weather               0.94                 0.65              0.57
# direct_report               0.85                 0.77              0.77
#
#                         macro_avg_f1  weighted_avg_precision  \
# related                         0.72                    0.81
# request                         0.81                    0.89
# offer                           0.54                    0.99
# aid_related                     0.75                    0.76
# medical_help                    0.66                    0.91
# medical_products                0.68                    0.94
# search_and_rescue               0.56                    0.96
# security                        0.50                    0.97
# military                        0.69                    0.96
# water                           0.74                    0.94
# food                            0.78                    0.91
# shelter                         0.73                    0.92
# clothing                        0.68                    0.98
# money                           0.60                    0.97
# missing_people                  0.60                    0.99
# refugees                        0.56                    0.95
# death                           0.72                    0.95
# other_aid                       0.56                    0.84
# infrastructure_related          0.56                    0.90
# transport                       0.62                    0.94
# buildings                       0.66                    0.94
# electricity                     0.61                    0.98
# tools                           0.50                    0.99
# hospitals                       0.50                    0.98
# shops                           0.52                    0.99
# aid_centers                     0.51                    0.98
# other_infrastructure            0.55                    0.93
# weather_related                 0.80                    0.84
# floods                          0.74                    0.92
# storm                           0.78                    0.92
# fire                            0.53                    0.98
# earthquake                      0.80                    0.94
# cold                            0.67                    0.98
# other_weather                   0.59                    0.93
# direct_report                   0.77                    0.85
#
#                         weighted_avg_recall  weighted_avg_f1
# related                                0.82             0.81
# request                                0.89             0.89
# offer                                  0.99             0.99
# aid_related                            0.76             0.76
# medical_help                           0.93             0.91
# medical_products                       0.95             0.94
# search_and_rescue                      0.97             0.96
# security                               0.98             0.97
# military                               0.97             0.96
# water                                  0.94             0.94
# food                                   0.92             0.91
# shelter                                0.93             0.92
# clothing                               0.98             0.98
# money                                  0.98             0.97
# missing_people                         0.99             0.99
# refugees                               0.97             0.95
# death                                  0.96             0.95
# other_aid                              0.87             0.83
# infrastructure_related                 0.93             0.91
# transport                              0.95             0.94
# buildings                              0.95             0.94
# electricity                            0.98             0.97
# tools                                  0.99             0.99
# hospitals                              0.99             0.98
# shops                                  0.99             0.99
# aid_centers                            0.99             0.98
# other_infrastructure                   0.95             0.94
# weather_related                        0.84             0.84
# floods                                 0.93             0.92
# storm                                  0.93             0.93
# fire                                   0.99             0.98
# earthquake                             0.94             0.94
# cold                                   0.98             0.98
# other_weather                          0.94             0.93
# direct_report                          0.85             0.85

# %%
#Calculate Metrics for the NB Model
report_multinb.mean()
# Out:
# accuracy                  0.940571
# macro_avg_precision       0.735429
# macro_avg_recall          0.623429
# macro_avg_f1              0.645429
# weighted_avg_precision    0.932286
# weighted_avg_recall       0.940571
# weighted_avg_f1           0.932571
# dtype: float64

# %% [markdown]
# ***8.2 ADA Boost Classifier***

# %%
# Trying ADA Boost classifier

pipe_ada = Pipeline([ 
    ('vect', CountVectorizer(tokenizer=tokenize)),
    ('tfidf', TfidfTransformer()),
    ('clf', multioutput.MultiOutputClassifier(AdaBoostClassifier(random_state=42)))
])

pipe_ada.fit(X_train, y_train)

pipe_ada.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'vect', 'tfidf', 'clf', 'vect__analyzer', 'vect__binary', 'vect__decode_error', 'vect__dtype', 'vect__encoding', 'vect__input', 'vect__lowercase', 'vect__max_df', 'vect__max_features', 'vect__min_df', 'vect__ngram_range', 'vect__preprocessor', 'vect__stop_words', 'vect__strip_accents', 'vect__token_pattern', 'vect__tokenizer', 'vect__vocabulary', 'tfidf__norm', 'tfidf__smooth_idf', 'tfidf__sublinear_tf', 'tfidf__use_idf', 'clf__estimator__algorithm', 'clf__estimator__base_estimator', 'clf__estimator__learning_rate', 'clf__estimator__n_estimators', 'clf__estimator__random_state', 'clf__estimator', 'clf__n_jobs'])

# %%
# Grid search for parameters
params = {
    'tfidf__use_idf' : (True, False),
    'clf__estimator__n_estimators' : [50, 100],
    'clf__estimator__random_state' : [42],
    'clf__estimator__learning_rate' : [0.5] 
}

gs_ada = GridSearchCV(pipe_ada, param_grid=params, refit=True, cv=10, n_jobs=-1, verbose=1, return_train_score=True)
gs_ada
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('vect',
#                                         CountVectorizer(tokenizer=<function tokenize at 0x7fc990e729d0>)),
#                                        ('tfidf', TfidfTransformer()),
#                                        ('clf',
#                                         MultiOutputClassifier(estimator=AdaBoostClassifier()))]),
#              n_jobs=-1,
#              param_grid={'clf__estimator__learning_rate': [0.5],
#                          'clf__estimator__n_estimators': [50, 100],
#                          'clf__estimator__random_state': [42],
#                          'tfidf__use_idf': (True, False)},
#              return_train_score=True, verbose=1)

# %%
best_ada = gs_ada.fit(X_train, y_train)

#print('Best Model :', gs_ada.best_score_)
print('Params :', best_ada.best_params_)
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# Params : {'clf__estimator__learning_rate': 0.5, 'clf__estimator__n_estimators': 100, 'clf__estimator__random_state': 42, 'tfidf__use_idf': True}

# %%
# Evaluate ADA Boost Classifier Model with best parameters
gsada = best_ada.best_estimator_
report_gsada = evaluate_model(gsada, X_test, y_test, y_test.columns)
report_gsada
# Out:
#                         accuracy  macro_avg_precision  macro_avg_recall  \
# related                     0.80                 0.76              0.62
# request                     0.90                 0.86              0.75
# offer                       1.00                 0.50              0.50
# aid_related                 0.76                 0.77              0.74
# medical_help                0.93                 0.79              0.59
# medical_products            0.96                 0.84              0.63
# search_and_rescue           0.97                 0.87              0.56
# security                    0.98                 0.66              0.50
# military                    0.97                 0.83              0.62
# water                       0.96                 0.87              0.82
# food                        0.95                 0.88              0.84
# shelter                     0.94                 0.88              0.75
# clothing                    0.99                 0.85              0.67
# money                       0.98                 0.78              0.61
# missing_people              0.99                 0.82              0.59
# refugees                    0.97                 0.78              0.58
# death                       0.97                 0.88              0.69
# other_aid                   0.87                 0.73              0.54
# infrastructure_related      0.94                 0.76              0.53
# transport                   0.96                 0.84              0.59
# buildings                   0.96                 0.85              0.66
# electricity                 0.98                 0.89              0.61
# tools                       0.99                 1.00              0.52
# hospitals                   0.99                 0.63              0.52
# shops                       1.00                 0.50              0.50
# aid_centers                 0.99                 0.67              0.53
# other_infrastructure        0.96                 0.73              0.52
# weather_related             0.87                 0.88              0.80
# floods                      0.96                 0.93              0.77
# storm                       0.94                 0.87              0.74
# fire                        0.99                 0.78              0.60
# earthquake                  0.97                 0.94              0.88
# cold                        0.98                 0.89              0.66
# other_weather               0.95                 0.71              0.53
# direct_report               0.87                 0.83              0.71
#
#                         macro_avg_f1  weighted_avg_precision  \
# related                         0.64                    0.79
# request                         0.79                    0.89
# offer                           0.50                    0.99
# aid_related                     0.74                    0.76
# medical_help                    0.62                    0.91
# medical_products                0.68                    0.95
# search_and_rescue               0.60                    0.97
# security                        0.50                    0.97
# military                        0.67                    0.96
# water                           0.84                    0.96
# food                            0.86                    0.95
# shelter                         0.80                    0.94
# clothing                        0.72                    0.99
# money                           0.66                    0.97
# missing_people                  0.64                    0.99
# refugees                        0.62                    0.96
# death                           0.75                    0.96
# other_aid                       0.55                    0.84
# infrastructure_related          0.53                    0.92
# transport                       0.63                    0.95
# buildings                       0.72                    0.95
# electricity                     0.67                    0.98
# tools                           0.54                    0.99
# hospitals                       0.53                    0.98
# shops                           0.50                    0.99
# aid_centers                     0.55                    0.98
# other_infrastructure            0.53                    0.94
# weather_related                 0.83                    0.88
# floods                          0.83                    0.96
# storm                           0.79                    0.93
# fire                            0.64                    0.99
# earthquake                      0.90                    0.97
# cold                            0.72                    0.98
# other_weather                   0.54                    0.93
# direct_report                   0.75                    0.86
#
#                         weighted_avg_recall  weighted_avg_f1
# related                                0.80             0.77
# request                                0.90             0.89
# offer                                  1.00             0.99
# aid_related                            0.76             0.75
# medical_help                           0.93             0.91
# medical_products                       0.96             0.95
# search_and_rescue                      0.97             0.96
# security                               0.98             0.97
# military                               0.97             0.96
# water                                  0.96             0.96
# food                                   0.95             0.95
# shelter                                0.94             0.94
# clothing                               0.99             0.99
# money                                  0.98             0.97
# missing_people                         0.99             0.99
# refugees                               0.97             0.96
# death                                  0.97             0.96
# other_aid                              0.87             0.83
# infrastructure_related                 0.94             0.91
# transport                              0.96             0.95
# buildings                              0.96             0.95
# electricity                            0.98             0.98
# tools                                  0.99             0.99
# hospitals                              0.99             0.98
# shops                                  1.00             0.99
# aid_centers                            0.99             0.98
# other_infrastructure                   0.96             0.94
# weather_related                        0.87             0.87
# floods                                 0.96             0.95
# storm                                  0.94             0.93
# fire                                   0.99             0.99
# earthquake                             0.97             0.97
# cold                                   0.98             0.98
# other_weather                          0.95             0.93
# direct_report                          0.87             0.85

# %%
report_gsada.mean()
# Out:
# accuracy                  0.948286
# macro_avg_precision       0.801429
# macro_avg_recall          0.636286
# macro_avg_f1              0.668000
# weighted_avg_precision    0.940857
# weighted_avg_recall       0.948286
# weighted_avg_f1           0.938286
# dtype: float64

# %%
# Testing with some sample texts
test_text = ['there is a storm and people are trapped']
test = best_ada.predict(test_text)
print(y_train.columns.values[(test.flatten()==1)])
# Out:
# ['related' 'aid_related' 'weather_related' 'storm']

# %%
test_text = ['we are having an earthquake, buildings are destroyed, victims need food']
test = best_ada.predict(test_text)
print(y_train.columns.values[(test.flatten()==1)])

test_text_1 = ['we are having an earthquake, buildings are destroyed, victims need food']
test_1 = gs_nb.predict(test_text)
print(y_train.columns.values[(test_1.flatten()==1)])

test_text_2 = ['we are having an earthquake, buildings are destroyed, victims need food']
test_2 = gs.predict(test_text)
print(y_train.columns.values[(test_2.flatten()==1)])
# Out:
# ['related' 'request' 'aid_related' 'buildings' 'weather_related'
#  'earthquake' 'direct_report']
# ['related' 'aid_related' 'buildings' 'weather_related' 'earthquake'
#  'direct_report']
# ['related']

# %% [markdown]
# As we see above, the text predictions for the same message are most accurate for the ADA Boost Classifier, followed by the Multinomial Naive Bayes and finally the Random Classifier.

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
pickle.dump(best_ada, open('classifier.pkl', 'wb'))

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.

# %%
import sys


def load_data(database_filepath):
    pass


def tokenize(text):
    pass


def build_model():
    pass


def evaluate_model(model, X_test, Y_test, category_names):
    pass


def save_model(model, model_filepath):
    pass


def main():
    if len(sys.argv) == 3:
        database_filepath, model_filepath = sys.argv[1:]
        print('Loading data...\n    DATABASE: {}'.format(database_filepath))
        X, Y, category_names = load_data(database_filepath)
        X_train, X_test, Y_train, Y_test = train_test_split(
            X, Y, test_size=0.2)

        print('Building model...')
        model = build_model()

        print('Training model...')
        model.fit(X_train, Y_train)

        print('Evaluating model...')
        evaluate_model(model, X_test, Y_test, category_names)

        print('Saving model...\n    MODEL: {}'.format(model_filepath))
        save_model(model, model_filepath)

        print('Trained model saved!')

    else:
        print('Please provide the filepath of the disaster messages database '
              'as the first argument and the filepath of the pickle file to '
              'save the model to as the second argument. \n\nExample: python '
              'train_classifier.py ../data/DisasterResponse.db classifier.pkl')


if __name__ == '__main__':
    main()
